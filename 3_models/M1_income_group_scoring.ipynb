# %% [markdown]
# # Global Entities - Map Visualizer

# %% [markdown]
# #### Version 1.0

# %% [markdown]
# ### TODO
#
# - Plotly basic map plot
# - Plotly with group level filter
# - Plotly with entity filter for group
# - Plotly lineplot/scatterplot/heatmap for selected entity
# - Plotly Dash app

# %% [markdown]
# ### Observations

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Packages

# %%
from datetime import datetime, date
from pprint import pprint
from collections import OrderedDict
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Set ipython's max row display
# pd.set_option('display.max_row', 1000)
# Set iPython's max column width
pd.set_option('display.max_columns', 50)

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [20, 10]

# %% [markdown]
# ### Functions

# %%
def masked_heatmap():
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    fig,ax = plt.subplots()
    sns.heatmap(corr,center = 0, fmt = ".3f", square = True, annot= True, mask=mask)

# %% [markdown]
# ## Global Variables

# %% [markdown]
# #### Dataset Parameters

# %%
file_name = '../data/silver_tables/yearly_values_per_entity.csv'

year_range = [1960, 2022]
metric_agg = 'last_year'
metric_agg = 'growth_rate'
metric_agg = '?'

# %%
country_list = ['United Arab Emirates', 'Japan', 'Ghana'] #For country level analysis

# %%
key_columns = [
    'Annual CO2 emissions', 'Annual change in primary energy consumption (%)',
    'Per capita electricity (kWh)',
    'Fossil fuels per capita (kWh)', 'Fossil fuels (% equivalent primary energy)',
    'Renewables per capita (kWh - equivalent)', 'Renewables (% electricity)',
    'Solar Generation - TWh', 'prod of Electricity from solar (TWh)',
]

corr_columns = [
    'Annual CO2 emissions', 'Annual change in primary energy consumption (%)',
    'Per capita electricity (kWh)',
    'Fossil fuels per capita (kWh)',
    'Renewables per capita (kWh - equivalent)',
]

# %% [markdown]
# ## Data Prep

# %%
df_original = pd.read_csv(file_name)

# %%
df_original = df_original.loc[
    (df_original['Year'] > year_range[0])
    & (df_original['Year'] < year_range[1])
]

# %%
df_original.head(2)
# Out:
#    Entity  Year Code                     Region Income group Lending category  \
# 34  Aruba  1961  ABW  Latin America & Caribbean  High income              NaN
# 35  Aruba  1962  ABW  Latin America & Caribbean  High income              NaN
#
#     Fossil fuels per capita (kWh)  Oil Consumption - TWh Economy  \
# 34                            NaN                    NaN   Aruba
# 35                            NaN                    NaN   Aruba
#
#     Coal (TWh, direct energy)  Geo Biomass Other - TWh  Wind Generation - TWh  \
# 34                        NaN                      NaN                    NaN
# 35                        NaN                      NaN                    NaN
#
#     Fossil fuels (% equivalent primary energy)  \
# 34                                         NaN
# 35                                         NaN
#
#     prod of Other renewables including bioenergy (TWh)  Coal Production - TWh  \
# 34                                                NaN                     NaN
# 35                                                NaN                     NaN
#
#     Gas Production - TWh  Gas (TWh, direct energy)  \
# 34                   NaN                       NaN
# 35                   NaN                       NaN
#
#     Per capita electricity (kWh)  Renewables (% electricity)  \
# 34                           NaN                         NaN
# 35                           NaN                         NaN
#
#     Annual CO2 emissions  Fossil fuels (TWh)  Hydro Generation - TWh  \
# 34              645553.0                 NaN                     NaN
# 35              708942.0                 NaN                     NaN
#
#     Oil Production - TWh  Population density (people per sq. km of land area)  \
# 34                   NaN                                         307.966667
# 35                   NaN                                         312.411111
#
#     Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# 34                     NaN                                       NaN
# 35                     NaN                                       NaN
#
#     prod of Electricity from solar (TWh)  \
# 34                                   NaN
# 35                                   NaN
#
#     Annual change in primary energy consumption (%)  Solar Generation - TWh  \
# 34                                              NaN                     NaN
# 35                                              NaN                     NaN
#
#     Land area (sq. km)  Gas Consumption - TWh  Oil (TWh, direct energy)  \
# 34               180.0                    NaN                       NaN
# 35               180.0                    NaN                       NaN
#
#     prod of Electricity from hydro (TWh)  Fossil fuels (% growth)  \
# 34                                   NaN                      NaN
# 35                                   NaN                      NaN
#
#     prod of Electricity from wind (TWh) Entity_Category
# 34                                  NaN         Country
# 35                                  NaN         Country

# %%
df_original.describe()
# Out:
#                Year  Fossil fuels per capita (kWh)  Oil Consumption - TWh  \
# count  13231.000000                    4270.000000            4299.000000
# mean    1991.724662                   32590.368226            1015.737954
# std       17.303559                   34472.620328            4706.367669
# min     1961.000000                     155.807388               0.097381
# 25%     1977.000000                   11678.774170              65.349743
# 50%     1992.000000                   25363.719727             142.951569
# 75%     2007.000000                   40195.003906             418.514847
# max     2021.000000                  308704.218750           53368.628906
#
#        Coal (TWh, direct energy)  Geo Biomass Other - TWh  \
# count                  57.000000              4230.000000
# mean                28584.640556                 5.525746
# std                 10007.255369                34.808495
# min                 16060.809570                 0.000000
# 25%                 20363.539062                 0.000000
# 50%                 25963.681641                 0.046381
# 75%                 40175.359375                 1.373498
# max                 45161.207031               762.782654
#
#        Wind Generation - TWh  Fossil fuels (% equivalent primary energy)  \
# count            4230.000000                                 4270.000000
# mean                6.126806                                   86.307820
# std                61.993965                                   15.585076
# min                 0.000000                                   12.804697
# 25%                 0.000000                                   80.717112
# 50%                 0.000000                                   91.689793
# 75%                 0.070833                                   97.799118
# max              1861.939819                                  100.000015
#
#        prod of Other renewables including bioenergy (TWh)  \
# count                                        7050.000000
# mean                                            3.366912
# std                                            27.092075
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.368750
# max                                           762.782654
#
#        Coal Production - TWh  Gas Production - TWh  Gas (TWh, direct energy)  \
# count            1397.000000           2514.000000                 57.000000
# mean             1915.282764            941.158999              21492.190695
# std              6167.601614           3615.938174               9564.826179
# min                 0.339596              0.000000               6303.798828
# 25%                37.385506             45.443999              14118.032227
# 50%               125.336014            144.380302              20265.484375
# 75%               815.064575            404.810089              29315.390625
# max             46550.605469          40368.828125              40374.605469
#
#        Per capita electricity (kWh)  Renewables (% electricity)  \
# count                   5828.000000                 5665.000000
# mean                    3924.760158                   29.633481
# std                     5117.133819                   32.033628
# min                        0.000000                    0.000000
# 25%                      572.427170                    1.366416
# 50%                     2469.344605                   16.124605
# 75%                     5388.259033                   53.125000
# max                    56781.601560                  100.000000
#
#        Annual CO2 emissions  Fossil fuels (TWh)  Hydro Generation - TWh  \
# count          1.265100e+04         4270.000000             4292.000000
# mean           2.164809e+08         2346.057603               62.145414
# std            1.755023e+09        11082.105692              308.745114
# min            3.664000e+03            0.097381                0.000000
# 25%            6.012190e+05          117.750929                0.430750
# 50%            5.064147e+06          283.652481                4.616636
# 75%            4.262826e+07          967.343674               23.120900
# max            3.670250e+10       136131.468750             4345.990234
#
#        Oil Production - TWh  \
# count           2553.000000
# mean            1707.803287
# std             5858.493747
# min                0.000000
# 25%              102.900040
# 50%              344.998383
# 75%             1131.237549
# max            52181.949219
#
#        Population density (people per sq. km of land area)  \
# count                                       11042.000000
# mean                                          270.028485
# std                                          1308.026452
# min                                             0.098625
# 25%                                            19.113774
# 50%                                            63.247178
# 75%                                           149.543597
# max                                         21388.600000
#
#        Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# count             4273.000000                               4292.000000
# mean               756.214677                                  4.578573
# std               3785.186997                                 13.474483
# min                  0.000000                                  0.000000
# 25%                  3.395960                                  0.172228
# 50%                 32.584167                                  0.806088
# 75%                169.332794                                  2.851986
# max              45161.207031                                153.883406
#
#        prod of Electricity from solar (TWh)  \
# count                           7113.000000
# mean                               1.344705
# std                               22.090646
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.002000
# max                             1032.501221
#
#        Annual change in primary energy consumption (%)  \
# count                                      9354.000000
# mean                                          4.533664
# std                                          31.757811
# min                                         -95.005081
# 25%                                          -0.781557
# 50%                                           2.361172
# 75%                                           6.958872
# max                                        1553.104980
#
#        Solar Generation - TWh  Land area (sq. km)  Gas Consumption - TWh  \
# count             4230.000000        1.197800e+04            4296.000000
# mean                 2.250895        6.467467e+05             564.805312
# std                 28.611929        1.812242e+06            2785.492795
# min                  0.000000        1.000000e+01               0.000000
# 25%                  0.000000        1.827000e+04               8.854822
# 50%                  0.000000        1.074000e+05              53.573006
# 75%                  0.005899        4.727100e+05             241.780823
# max               1032.501221        1.638995e+07           40374.605469
#
#        Oil (TWh, direct energy)  prod of Electricity from hydro (TWh)  \
# count                 57.000000                           7178.000000
# mean               39160.740543                             38.012262
# std                 8988.199100                            240.564170
# min                17989.603516                              0.000000
# 25%                33680.054688                              0.017904
# 50%                38151.847656                              1.560000
# 75%                47172.609375                              9.962750
# max                53368.628906                           4345.990234
#
#        Fossil fuels (% growth)  prod of Electricity from wind (TWh)
# count              4255.000000                          7113.000000
# mean                  3.538322                             3.658208
# std                  26.995583                            47.898591
# min                 -49.590828                             0.000000
# 25%                  -1.007167                             0.000000
# 50%                   2.493978                             0.000000
# 75%                   6.371659                             0.006000
# max                1553.104980                          1861.939819

# %%
df = df_original.copy()

# %% [markdown]
# ## Scoring

# %% [markdown]
# #### Validation

# %%
df[
    df["Income group"].isnull()].query(
    "Year == 2020 and Entity_Category == 'Country'"
    )['Entity'].value_counts()
# Out:
# Montserrat                         1
# Reunion                            1
# Guadeloupe                         1
# Saint Pierre And Miquelon          1
# Anguilla                           1
# Ussr                               1
# Falkland Islands                   1
# Western Sahara                     1
# Bonaire Sint Eustatius And Saba    1
# Mayotte                            1
# Niue                               1
# Cook Islands                       1
# Venezuela                          1
# Wallis And Futuna                  1
# Kosovo                             1
# Martinique                         1
# Saint Helena                       1
# French Guiana                      1
# Name: Entity, dtype: int64

# %%
df.query("Year == 2020 and Entity_Category == 'Country'")["Income group"].value_counts(dropna=False)
# Out:
# High income            75
# Lower middle income    54
# Upper middle income    53
# Low income             28
# NaN                    18
# Name: Income group, dtype: int64

# %%
df["Income group"].unique()

# Land area (sq. km)## 
# Annual CO2 emissions
## Income group

# nan,    -----------------> x0
# "High income" -----------> x1
# "Upper middle income", --> x1.5
# "Lower middle income", --> x1.75
# "Low income",  ----------> x2



# Score = (Annual CO2 emissions * Land Area) * Income Factor
# Out:
# array(['High income', 'Low income', 'Lower middle income', nan,
#        'Upper middle income'], dtype=object)

# %% [markdown]
# ### Map Income Group to Income Factor number

# %%
def income_group_mapping(text):
    if text == "High income":
        return 1
    if text == "Upper middle income":
        return 1.25
    if text == "Lower middle income":
        return 1.75
    if text == "Low income":
        return 2
    return 1

# %%
df["income_factor"] = df["Income group"].apply(lambda x: income_group_mapping(x))

# %%
df["income_factor"].describe()
# Out:
# count    13231.000000
# mean         1.360630
# std          0.377602
# min          1.000000
# 25%          1.000000
# 50%          1.250000
# 75%          1.750000
# max          2.000000
# Name: income_factor, dtype: float64

# %%
df.head(2)
# Out:
#    Entity  Year Code                     Region Income group Lending category  \
# 34  Aruba  1961  ABW  Latin America & Caribbean  High income              NaN
# 35  Aruba  1962  ABW  Latin America & Caribbean  High income              NaN
#
#     Fossil fuels per capita (kWh)  Oil Consumption - TWh Economy  \
# 34                            NaN                    NaN   Aruba
# 35                            NaN                    NaN   Aruba
#
#     Coal (TWh, direct energy)  Geo Biomass Other - TWh  Wind Generation - TWh  \
# 34                        NaN                      NaN                    NaN
# 35                        NaN                      NaN                    NaN
#
#     Fossil fuels (% equivalent primary energy)  \
# 34                                         NaN
# 35                                         NaN
#
#     prod of Other renewables including bioenergy (TWh)  Coal Production - TWh  \
# 34                                                NaN                     NaN
# 35                                                NaN                     NaN
#
#     Gas Production - TWh  Gas (TWh, direct energy)  \
# 34                   NaN                       NaN
# 35                   NaN                       NaN
#
#     Per capita electricity (kWh)  Renewables (% electricity)  \
# 34                           NaN                         NaN
# 35                           NaN                         NaN
#
#     Annual CO2 emissions  Fossil fuels (TWh)  Hydro Generation - TWh  \
# 34              645553.0                 NaN                     NaN
# 35              708942.0                 NaN                     NaN
#
#     Oil Production - TWh  Population density (people per sq. km of land area)  \
# 34                   NaN                                         307.966667
# 35                   NaN                                         312.411111
#
#     Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# 34                     NaN                                       NaN
# 35                     NaN                                       NaN
#
#     prod of Electricity from solar (TWh)  \
# 34                                   NaN
# 35                                   NaN
#
#     Annual change in primary energy consumption (%)  Solar Generation - TWh  \
# 34                                              NaN                     NaN
# 35                                              NaN                     NaN
#
#     Land area (sq. km)  Gas Consumption - TWh  Oil (TWh, direct energy)  \
# 34               180.0                    NaN                       NaN
# 35               180.0                    NaN                       NaN
#
#     prod of Electricity from hydro (TWh)  Fossil fuels (% growth)  \
# 34                                   NaN                      NaN
# 35                                   NaN                      NaN
#
#     prod of Electricity from wind (TWh) Entity_Category  income_factor  \
# 34                                  NaN         Country            1.0
# 35                                  NaN         Country            1.0
#
#     prioritization_score
# 34           145249425.0
# 35           159511950.0

# %% [markdown]
# ### Calculate Prioritization Score

# %% [markdown]
# #### Score Calculation Formula
# *Per Entity:*
# `prioritization_score` = `Annual CO2 emissions` * `Land area (sq. km)` * `income_factor`

# %%
entities_wo_area = df.drop_duplicates(['Code']).loc[df['Land area (sq. km)'].isna()]['Entity']

# %%
df.loc[df['Entity'].isin(
    entities_wo_area)][
    ['Entity', 'Year', 'Land area (sq. km)']].sort_values(
    'Land area (sq. km)')
# Out:
#                   Entity  Year  Land area (sq. km)
# 11895         Luxembourg  2000             2574.46
# 11915         Luxembourg  2020             2574.46
# 11914         Luxembourg  2019             2574.46
# 11913         Luxembourg  2018             2574.46
# 11912         Luxembourg  2017             2574.46
# ...                  ...   ...                 ...
# 21403  Wallis And Futuna  2016                 NaN
# 21404  Wallis And Futuna  2017                 NaN
# 21405  Wallis And Futuna  2018                 NaN
# 21406  Wallis And Futuna  2019                 NaN
# 21407  Wallis And Futuna  2020                 NaN
#
# [1175 rows x 3 columns]

# %%
df["prioritization_score"] = (
    df["Annual CO2 emissions"] * df['Land area (sq. km)']
)

# %%
df.sort_values(by='prioritization_score', ascending=False)
# Out:
#                   Entity  Year Code                      Region  \
# 3969               China  2020  CHN         East Asia & Pacific
# 3968               China  2019  CHN         East Asia & Pacific
# 3967               China  2018  CHN         East Asia & Pacific
# 3963               China  2014  CHN         East Asia & Pacific
# 3962               China  2013  CHN         East Asia & Pacific
# ...                  ...   ...  ...                         ...
# 21406  Wallis And Futuna  2019  WLF                         NaN
# 21407  Wallis And Futuna  2020  WLF                         NaN
# 21550              Yemen  2021  YEM  Middle East & North Africa
# 21688       South Africa  2021  ZAF          Sub-Saharan Africa
# 21878           Zimbabwe  2021  ZWE          Sub-Saharan Africa
#
#               Income group Lending category  Fossil fuels per capita (kWh)  \
# 3969   Upper middle income             IBRD                   23784.003906
# 3968   Upper middle income             IBRD                   23499.349609
# 3967   Upper middle income             IBRD                   23036.990234
# 3963   Upper middle income             IBRD                   22106.707031
# 3962   Upper middle income             IBRD                   21929.755859
# ...                    ...              ...                            ...
# 21406                  NaN              NaN                            NaN
# 21407                  NaN              NaN                            NaN
# 21550           Low income              IDA                            NaN
# 21688  Upper middle income             IBRD                   21795.685547
# 21878  Lower middle income            Blend                            NaN
#
#        Oil Consumption - TWh       Economy  Coal (TWh, direct energy)  \
# 3969             7984.452637         China                        NaN
# 3968             7915.177734         China                        NaN
# 3967             7534.662109         China                        NaN
# 3963             6142.516602         China                        NaN
# 3962             5907.469727         China                        NaN
# ...                      ...           ...                        ...
# 21406                    NaN           NaN                        NaN
# 21407                    NaN           NaN                        NaN
# 21550                    NaN   Yemen, Rep.                        NaN
# 21688             289.166656  South Africa                        NaN
# 21878                    NaN      Zimbabwe                        NaN
#
#        Geo Biomass Other - TWh  Wind Generation - TWh  \
# 3969                135.625000             466.500000
# 3968                112.725227             405.299988
# 3967                 93.725227             365.799988
# 3963                 46.268219             159.762695
# 3962                 37.132999             138.264130
# ...                        ...                    ...
# 21406                      NaN                    NaN
# 21407                      NaN                    NaN
# 21550                      NaN                    NaN
# 21688                 0.431334               8.188991
# 21878                      NaN                    NaN
#
#        Fossil fuels (% equivalent primary energy)  \
# 3969                                    83.505882
# 3968                                    84.277794
# 3967                                    85.251244
# 3963                                    88.808533
# 3962                                    90.179047
# ...                                           ...
# 21406                                         NaN
# 21407                                         NaN
# 21550                                         NaN
# 21688                                   94.631485
# 21878                                         NaN
#
#        prod of Other renewables including bioenergy (TWh)  \
# 3969                                          135.625000
# 3968                                          112.725227
# 3967                                           93.725227
# 3963                                           46.268219
# 3962                                           37.132999
# ...                                                  ...
# 21406                                                NaN
# 21407                                                NaN
# 21550                                                NaN
# 21688                                           0.431334
# 21878                                                NaN
#
#        Coal Production - TWh  Gas Production - TWh  Gas (TWh, direct energy)  \
# 3969            22364.935547           1940.092163                       NaN
# 3968            22154.439453           1767.414429                       NaN
# 3967            21352.949219           1614.188599                       NaN
# 3963            21680.763672           1311.808472                       NaN
# 3962            22034.134766           1218.107178                       NaN
# ...                      ...                   ...                       ...
# 21406                    NaN                   NaN                       NaN
# 21407                    NaN                   NaN                       NaN
# 21550                    NaN              3.977500                       NaN
# 21688            1541.734863                   NaN                       NaN
# 21878              24.290951                   NaN                       NaN
#
#        Per capita electricity (kWh)  Renewables (% electricity)  \
# 3969                    5459.258789                   28.087379
# 3968                    5277.177246                   26.848570
# 3967                    5057.009277                   25.610914
# 3963                    4183.150879                   22.249449
# 3962                    3947.121094                   20.129911
# ...                             ...                         ...
# 21406                           NaN                         NaN
# 21407                           NaN                         NaN
# 21550                           NaN                         NaN
# 21688                   4113.701660                    7.334341
# 21878                           NaN                         NaN
#
#        Annual CO2 emissions  Fossil fuels (TWh)  Hydro Generation - TWh  \
# 3969           1.066789e+10        34232.882812             1321.708984
# 3968           1.048999e+10        33692.988281             1272.537964
# 3967           1.028999e+10        32888.707031             1198.886963
# 3963           9.985583e+09        30937.318359             1059.691650
# 3962           9.952744e+09        30523.664062              909.612244
# ...                     ...                 ...                     ...
# 21406          2.643700e+04                 NaN                     NaN
# 21407          2.647400e+04                 NaN                     NaN
# 21550                   NaN                 NaN                     NaN
# 21688                   NaN         1308.656494                1.401010
# 21878                   NaN                 NaN                     NaN
#
#        Oil Production - TWh  \
# 3969            2265.163574
# 3968            2228.633545
# 3967            2201.838135
# 3963            2458.919189
# 3962            2441.826416
# ...                     ...
# 21406                   NaN
# 21407                   NaN
# 21550             32.096210
# 21688                   NaN
# 21878                   NaN
#
#        Population density (people per sq. km of land area)  \
# 3969                                          149.723553
# 3968                                          149.367573
# 3967                                          148.838644
# 3963                                          145.560051
# 3962                                          144.645433
# ...                                                  ...
# 21406                                                NaN
# 21407                                                NaN
# 21550                                                NaN
# 21688                                                NaN
# 21878                                                NaN
#
#        Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# 3969             22882.255859                                  4.056631
# 3968             22694.042969                                  3.768683
# 3967             22514.785156                                  3.460874
# 3963             22911.171875                                  2.538375
# 3962             22897.412109                                  2.178754
# ...                       ...                                       ...
# 21406                     NaN                                       NaN
# 21407                     NaN                                       NaN
# 21550                     NaN                                       NaN
# 21688              980.955627                                  0.785076
# 21878                     NaN                                       NaN
#
#        prod of Electricity from solar (TWh)  \
# 3969                             261.100006
# 3968                             224.000000
# 3967                             176.899994
# 3963                              23.512159
# 3962                               8.373886
# ...                                     ...
# 21406                                   NaN
# 21407                                   NaN
# 21550                                   NaN
# 21688                              7.898076
# 21878                                   NaN
#
#        Annual change in primary energy consumption (%)  \
# 3969                                          2.541566
# 3968                                          3.628755
# 3967                                          3.951335
# 3963                                          2.919328
# 3962                                          3.762960
# ...                                                ...
# 21406                                              NaN
# 21407                                              NaN
# 21550                                              NaN
# 21688                                         0.518334
# 21878                                              NaN
#
#        Solar Generation - TWh  Land area (sq. km)  Gas Consumption - TWh  \
# 3969               261.100006           9424702.9            3366.172607
# 3968               224.000000           9424702.9            3083.768555
# 3967               176.899994           9424702.9            2839.260010
# 3963                23.512159           9424701.3            1883.631348
# 3962                 8.373886           9424701.3            1718.785400
# ...                       ...                 ...                    ...
# 21406                     NaN                 NaN                    NaN
# 21407                     NaN                 NaN                    NaN
# 21550                     NaN                 NaN                    NaN
# 21688                7.898076                 NaN              38.534122
# 21878                     NaN                 NaN                    NaN
#
#        Oil (TWh, direct energy)  prod of Electricity from hydro (TWh)  \
# 3969                        NaN                           1321.708984
# 3968                        NaN                           1272.537964
# 3967                        NaN                           1198.886963
# 3963                        NaN                           1059.691650
# 3962                        NaN                            909.612244
# ...                         ...                                   ...
# 21406                       NaN                                   NaN
# 21407                       NaN                                   NaN
# 21550                       NaN                                   NaN
# 21688                       NaN                              1.401010
# 21878                       NaN                                   NaN
#
#        Fossil fuels (% growth)  prod of Electricity from wind (TWh)  \
# 3969                  1.602399                           466.500000
# 3968                  2.445459                           405.299988
# 3967                  2.862144                           365.799988
# 3963                  1.355195                           159.762695
# 3962                  3.184760                           138.264130
# ...                        ...                                  ...
# 21406                      NaN                                  NaN
# 21407                      NaN                                  NaN
# 21550                      NaN                                  NaN
# 21688                 0.948727                             8.188991
# 21878                      NaN                                  NaN
#
#       Entity_Category  income_factor  prioritization_score
# 3969          Country           1.25          1.005417e+17
# 3968          Country           1.25          9.886503e+16
# 3967          Country           1.25          9.698009e+16
# 3963          Country           1.25          9.411114e+16
# 3962          Country           1.25          9.380164e+16
# ...               ...            ...                   ...
# 21406         Country           1.00                   NaN
# 21407         Country           1.00                   NaN
# 21550         Country           2.00                   NaN
# 21688         Country           1.25                   NaN
# 21878         Country           1.75                   NaN
#
# [13231 rows x 38 columns]

# %%
df[["Entity", "Code"]].drop_duplicates()
# Out:
#                        Entity      Code
# 59263                   Aruba       ABW
# 59529             Afghanistan       AFG
# 59795                  Angola       AGO
# 60061                 Albania       ALB
# 60327    United Arab Emirates       ARE
# ...                       ...       ...
# 1910623               Eritrea       ERI
# 2278501             Gibraltar       GIB
# 2300047                Kosovo  OWID_KOS
# 2379049     Wallis And Futuna       WLF
# 2435707                 Timor       TLS
#
# [235 rows x 2 columns]

# %%
df["income_factor"].value_counts(dropna=False)
# Out:
# 1.25    1134540
# 1.75     826487
# 1.50     811063
# 2.00     438108
# 1.00     279303
# Name: income_factor, dtype: int64

# %%
df_original.query("Year == 2020")

## Land area (sq. km)
## Annual CO2 emissions
## Income group
# Out:
#                Entity  Year Code                      Region  \
# 71        Afghanistan  2020  AFG                  South Asia
# 208            Africa  2020  NaN                         NaN
# 264       Africa (Bp)  2020  NaN                         NaN
# 354           Albania  2020  ALB       Europe & Central Asia
# 459           Algeria  2020  DZA  Middle East & North Africa
# ...               ...   ...  ...                         ...
# 27414  Western Sahara  2020  NaN                         NaN
# 27685           World  2020  WLD                         NaN
# 27757           Yemen  2020  NaN                         NaN
# 27840          Zambia  2020  ZMB          Sub-Saharan Africa
# 27958        Zimbabwe  2020  ZWE          Sub-Saharan Africa
#
#               Income group Lending category  \
# 71              Low income              IDA
# 208                    NaN              NaN
# 264                    NaN              NaN
# 354    Upper middle income             IBRD
# 459    Lower middle income             IBRD
# ...                    ...              ...
# 27414                  NaN              NaN
# 27685                  NaN              NaN
# 27757                  NaN              NaN
# 27840           Low income              IDA
# 27958  Lower middle income            Blend
#
#        Fossil fuels (% equivalent primary energy)  Fossil fuels (% growth)  \
# 71                                            NaN                      NaN
# 208                                     89.685829                -6.705356
# 264                                     89.685829                -6.705356
# 354                                           NaN                      NaN
# 459                                     99.702103                -5.827147
# ...                                           ...                      ...
# 27414                                         NaN                      NaN
# 27685                                   82.211304                -5.385285
# 27757                                         NaN                      NaN
# 27840                                         NaN                      NaN
# 27958                                         NaN                      NaN
#
#        Gas Production - TWh  Land area (sq. km)  Unnamed: 0.1.1.1  \
# 71                      NaN        6.522300e+05           12892.0
# 208             2312.026855                 NaN              54.0
# 264             2312.026855                 NaN             110.0
# 354                     NaN        2.740000e+04           12893.0
# 459              814.563721        2.381741e+06             166.0
# ...                     ...                 ...               ...
# 27414                   NaN                 NaN           13179.0
# 27685          38615.152344        1.299798e+08            6032.0
# 27757              3.064353                 NaN           12870.0
# 27840                   NaN        7.433900e+05           13180.0
# 27958                   NaN        3.868500e+05           12873.0
#
#        Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# 71                        NaN                                       NaN
# 208               1157.901123                                  0.376615
# 264               1157.901123                                       NaN
# 354                       NaN                                       NaN
# 459                  4.816350                                  0.044457
# ...                       ...                                       ...
# 27414                     NaN                                       NaN
# 27685            41963.964844                                  2.704402
# 27757                     NaN                                       NaN
# 27840                     NaN                                       NaN
# 27958                     NaN                                       NaN
#
#        Wind Generation - TWh  \
# 71                       NaN
# 208                21.302896
# 264                21.302898
# 354                      NaN
# 459                 0.007700
# ...                      ...
# 27414                    NaN
# 27685            1596.428223
# 27757                    NaN
# 27840                    NaN
# 27958                    NaN
#
#        prod of Other renewables including bioenergy (TWh)  \
# 71                                              0.000000
# 208                                             8.066416
# 264                                             8.066416
# 354                                             0.000000
# 459                                             0.000000
# ...                                                  ...
# 27414                                           0.000000
# 27685                                         703.916443
# 27757                                           0.000000
# 27840                                           0.160000
# 27958                                           0.360000
#
#        Fossil fuels per capita (kWh)  Fossil fuels (TWh)  \
# 71                               NaN                 NaN
# 208                      3509.572021         4704.925781
# 264                              NaN         4704.925781
# 354                              NaN                 NaN
# 459                     14879.098633          652.463989
# ...                              ...                 ...
# 27414                            NaN                 NaN
# 27685                   16523.912109       128800.398438
# 27757                            NaN                 NaN
# 27840                            NaN                 NaN
# 27958                            NaN                 NaN
#
#        Oil Production - TWh  Coal Production - TWh  Hydro Generation - TWh  \
# 71                      NaN                    NaN                     NaN
# 208             3846.310547            1723.903687              146.373077
# 264             3846.310547            1723.903687              146.373077
# 354                     NaN                    NaN                     NaN
# 459              668.911072                    NaN                0.049600
# ...                     ...                    ...                     ...
# 27414                   NaN                    NaN                     NaN
# 27685          48508.015625           44068.472656             4345.990234
# 27757             43.814594                    NaN                     NaN
# 27840                   NaN                    NaN                     NaN
# 27958                   NaN              20.291876                     NaN
#
#        Unnamed: 0.1.1  prod of Electricity from solar (TWh)  \
# 71            12892.0                              0.040000
# 208              54.0                             16.058805
# 264             110.0                             16.058805
# 354           12893.0                              0.030000
# 459             166.0                              0.685000
# ...               ...                                   ...
# 27414         13179.0                              0.000000
# 27685          6032.0                            846.229370
# 27757         12870.0                              0.500000
# 27840         13180.0                              0.150000
# 27958         12873.0                              0.010000
#
#        prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# 71                                 0.620000       12892.0
# 208                              146.373077          54.0
# 264                              146.373077         110.0
# 354                                5.280000       12893.0
# 459                                0.049600         166.0
# ...                                     ...           ...
# 27414                              0.000000       13179.0
# 27685                           4345.990234        6032.0
# 27757                              0.000000       12870.0
# 27840                             13.670000       13180.0
# 27958                              7.260000       12873.0
#
#        Gas (TWh, direct energy)  \
# 71                          NaN
# 208                         NaN
# 264                         NaN
# 354                         NaN
# 459                         NaN
# ...                         ...
# 27414                       NaN
# 27685              38455.726562
# 27757                       NaN
# 27840                       NaN
# 27958                       NaN
#
#        Annual change in primary energy consumption (%)  \
# 71                                                 NaN
# 208                                          -5.539828
# 264                                          -5.539828
# 354                                                NaN
# 459                                          -5.824166
# ...                                                ...
# 27414                                              NaN
# 27685                                        -3.985941
# 27757                                              NaN
# 27840                                              NaN
# 27958                                              NaN
#
#        Geo Biomass Other - TWh  Coal (TWh, direct energy)  \
# 71                         NaN                        NaN
# 208                   8.066416                        NaN
# 264                   8.066416                        NaN
# 354                        NaN                        NaN
# 459                   0.000000                        NaN
# ...                        ...                        ...
# 27414                      NaN                        NaN
# 27685               703.916443               41963.964844
# 27757                      NaN                        NaN
# 27840                      NaN                        NaN
# 27958                      NaN                        NaN
#
#        Per capita electricity (kWh)  Oil Consumption - TWh  \
# 71                        20.014248                    NaN
# 208                      628.423706            2011.052612
# 264                             NaN            2011.052612
# 354                     1852.207153                    NaN
# 459                     1821.686035             211.635162
# ...                             ...                    ...
# 27414                      0.000000                    NaN
# 27685                   3429.322021           48380.710938
# 27757                    100.668922                    NaN
# 27840                    844.264526                    NaN
# 27958                    709.013306                    NaN
#
#        Renewables (% electricity)  \
# 71                      84.615395
# 208                     22.430740
# 264                     22.430740
# 354                    100.000000
# 459                      0.937777
# ...                           ...
# 27414                         NaN
# 27685                   27.864630
# 27757                   15.384615
# 27840                   87.484352
# 27958                   68.676872
#
#        Population density (people per sq. km of land area)  \
# 71                                             59.684990
# 208                                                  NaN
# 264                                                  NaN
# 354                                           103.571131
# 459                                            18.411340
# ...                                                  ...
# 27414                                                NaN
# 27685                                          59.731828
# 27757                                                NaN
# 27840                                          24.729894
# 27958                                          38.420388
#
#        Solar Generation - TWh  Gas Consumption - TWh  \
# 71                        NaN                    NaN
# 208                 16.058805            1535.972412
# 264                 16.058805            1535.972412
# 354                       NaN                    NaN
# 459                  0.685000             436.012512
# ...                       ...                    ...
# 27414                     NaN                    NaN
# 27685              846.229370           38455.726562
# 27757                     NaN                    NaN
# 27840                     NaN                    NaN
# 27958                     NaN                    NaN
#
#        Oil (TWh, direct energy)  Annual CO2 emissions  \
# 71                          NaN          1.216029e+07
# 208                         NaN          1.326044e+09
# 264                         NaN                   NaN
# 354                         NaN          4.534673e+06
# 459                         NaN          1.549955e+08
# ...                         ...                   ...
# 27414                       NaN                   NaN
# 27685              48380.710938          3.480726e+10
# 27757                       NaN          9.768313e+06
# 27840                       NaN          6.572938e+06
# 27958                       NaN          1.053134e+07
#
#        prod of Electricity from wind (TWh) Entity_Category
# 71                                0.000000         Country
# 208                              21.302896       Continent
# 264                              21.302898             Bp?
# 354                               0.000000         Country
# 459                               0.007700         Country
# ...                                    ...             ...
# 27414                             0.000000         Country
# 27685                          1596.428223           World
# 27757                             0.000000         Country
# 27840                             0.000000         Country
# 27958                             0.000000         Country
#
# [279 rows x 38 columns]
