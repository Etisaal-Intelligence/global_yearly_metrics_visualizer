# %% [markdown]
# # Global Entities - per Entity Group - Visualizer

# %% [markdown]
# #### Version 1.0

# %% [markdown]
# ### TODO
#
# - ~~Line plot for world~~
# - Line plot of aggregated countries and compare to world
# - ~~Line plot per country/region/income/etc~~
# - ~~Heatmap for corellation between metrics per entity~~
# - Correlation between metrics across entities

# %% [markdown]
# ### Observations

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Packages

# %%
from datetime import datetime, date
from pprint import pprint
from collections import OrderedDict
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Set ipython's max row display
# pd.set_option('display.max_row', 1000)
# Set iPython's max column width
pd.set_option('display.max_columns', 50)

sns.set_style("darkgrid")
plt.rcParams['figure.figsize'] = [20, 10]

# %% [markdown]
# ### Functions

# %%
def masked_heatmap():
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    fig,ax = plt.subplots()
    sns.heatmap(corr,center = 0, fmt = ".3f", square = True, annot= True, mask=mask)

# %% [markdown]
# ## Global Variables

# %% [markdown]
# #### Dataset Parameters

# %%
file_name = '../data/silver_tables/yearly_values_per_entity.csv'

year_range = [1960, 2022]
metric_agg = 'last_year'
metric_agg = 'growth_rate'
metric_agg = '?'

# %%
country_list = ['United Arab Emirates', 'Japan', 'Ghana'] #For country level analysis

# %%
key_columns = [
    'Annual CO2 emissions', 'Annual change in primary energy consumption (%)',
    'Per capita electricity (kWh)',
    'Fossil fuels per capita (kWh)', 'Fossil fuels (% equivalent primary energy)',
    'Renewables per capita (kWh - equivalent)', 'Renewables (% electricity)',
    'Solar Generation - TWh', 'prod of Electricity from solar (TWh)',
]

corr_columns = [
    'Annual CO2 emissions', 'Annual change in primary energy consumption (%)',
    'Per capita electricity (kWh)',
    'Fossil fuels per capita (kWh)',
    'Renewables per capita (kWh - equivalent)',
]

# %% [markdown]
# ## Data Prep

# %%
df_original = pd.read_csv(file_name)

# %%
df_original = df_original.loc[
    (df_original['Year'] > year_range[0])
    & (df_original['Year'] < year_range[1])
]

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17013 entries, 12 to 27959
# Data columns (total 38 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Entity                                               17013 non-null  object
#  1   Year                                                 17013 non-null  int64
#  2   Code                                                 10529 non-null  object
#  3   Region                                               10407 non-null  object
#  4   Income group                                         10407 non-null  object
#  5   Lending category                                     7279 non-null   object
#  6   Fossil fuels (% equivalent primary energy)           6068 non-null   float64
#  7   Fossil fuels (% growth)                              6034 non-null   float64
#  8   Gas Production - TWh                                 4053 non-null   float64
#  9   Land area (sq. km)                                   10559 non-null  float64
#  10  Unnamed: 0.1.1.1                                     13164 non-null  float64
#  11  Coal Consumption - TWh                               6134 non-null   float64
#  12  Renewables per capita (kWh - equivalent)             4862 non-null   float64
#  13  Wind Generation - TWh                                5939 non-null   float64
#  14  prod of Other renewables including bioenergy (TWh)   8899 non-null   float64
#  15  Fossil fuels per capita (kWh)                        4840 non-null   float64
#  16  Fossil fuels (TWh)                                   6068 non-null   float64
#  17  Oil Production - TWh                                 4408 non-null   float64
#  18  Coal Production - TWh                                2500 non-null   float64
#  19  Hydro Generation - TWh                               6153 non-null   float64
#  20  Unnamed: 0.1.1                                       13164 non-null  float64
#  21  prod of Electricity from solar (TWh)                 8939 non-null   float64
#  22  prod of Electricity from hydro (TWh)                 9170 non-null   float64
#  23  Unnamed: 0.1                                         13164 non-null  float64
#  24  Gas (TWh, direct energy)                             57 non-null     float64
#  25  Annual change in primary energy consumption (%)      12261 non-null  float64
#  26  Geo Biomass Other - TWh                              5948 non-null   float64
#  27  Coal (TWh, direct energy)                            57 non-null     float64
#  28  Per capita electricity (kWh)                         6220 non-null   float64
#  29  Oil Consumption - TWh                                6160 non-null   float64
#  30  Renewables (% electricity)                           7008 non-null   float64
#  31  Population density (people per sq. km of land area)  9717 non-null   float64
#  32  Solar Generation - TWh                               5924 non-null   float64
#  33  Gas Consumption - TWh                                6094 non-null   float64
#  34  Oil (TWh, direct energy)                             57 non-null     float64
#  35  Annual CO2 emissions                                 13723 non-null  float64
#  36  prod of Electricity from wind (TWh)                  8953 non-null   float64
#  37  Entity_Category                                      17013 non-null  object
# dtypes: float64(31), int64(1), object(6)
# memory usage: 5.1+ MB

# %%
df_original.head()
# Out:
#          Entity  Year Code      Region Income group Lending category  \
# 12  Afghanistan  1961  AFG  South Asia   Low income              IDA
# 13  Afghanistan  1962  AFG  South Asia   Low income              IDA
# 14  Afghanistan  1963  AFG  South Asia   Low income              IDA
# 15  Afghanistan  1964  AFG  South Asia   Low income              IDA
# 16  Afghanistan  1965  AFG  South Asia   Low income              IDA
#
#     Fossil fuels (% equivalent primary energy)  Fossil fuels (% growth)  \
# 12                                         NaN                      NaN
# 13                                         NaN                      NaN
# 14                                         NaN                      NaN
# 15                                         NaN                      NaN
# 16                                         NaN                      NaN
#
#     Gas Production - TWh  Land area (sq. km)  Unnamed: 0.1.1.1  \
# 12                   NaN            652230.0               NaN
# 13                   NaN            652230.0               NaN
# 14                   NaN            652230.0               NaN
# 15                   NaN            652230.0               NaN
# 16                   NaN            652230.0               NaN
#
#     Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# 12                     NaN                                       NaN
# 13                     NaN                                       NaN
# 14                     NaN                                       NaN
# 15                     NaN                                       NaN
# 16                     NaN                                       NaN
#
#     Wind Generation - TWh  prod of Other renewables including bioenergy (TWh)  \
# 12                    NaN                                                NaN
# 13                    NaN                                                NaN
# 14                    NaN                                                NaN
# 15                    NaN                                                NaN
# 16                    NaN                                                NaN
#
#     Fossil fuels per capita (kWh)  Fossil fuels (TWh)  Oil Production - TWh  \
# 12                            NaN                 NaN                   NaN
# 13                            NaN                 NaN                   NaN
# 14                            NaN                 NaN                   NaN
# 15                            NaN                 NaN                   NaN
# 16                            NaN                 NaN                   NaN
#
#     Coal Production - TWh  Hydro Generation - TWh  Unnamed: 0.1.1  \
# 12                    NaN                     NaN             NaN
# 13                    NaN                     NaN             NaN
# 14                    NaN                     NaN             NaN
# 15                    NaN                     NaN             NaN
# 16                    NaN                     NaN             NaN
#
#     prod of Electricity from solar (TWh)  \
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
#
#     prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# 12                                   NaN           NaN
# 13                                   NaN           NaN
# 14                                   NaN           NaN
# 15                                   NaN           NaN
# 16                                   NaN           NaN
#
#     Gas (TWh, direct energy)  Annual change in primary energy consumption (%)  \
# 12                       NaN                                              NaN
# 13                       NaN                                              NaN
# 14                       NaN                                              NaN
# 15                       NaN                                              NaN
# 16                       NaN                                              NaN
#
#     Geo Biomass Other - TWh  Coal (TWh, direct energy)  \
# 12                      NaN                        NaN
# 13                      NaN                        NaN
# 14                      NaN                        NaN
# 15                      NaN                        NaN
# 16                      NaN                        NaN
#
#     Per capita electricity (kWh)  Oil Consumption - TWh  \
# 12                           NaN                    NaN
# 13                           NaN                    NaN
# 14                           NaN                    NaN
# 15                           NaN                    NaN
# 16                           NaN                    NaN
#
#     Renewables (% electricity)  \
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
#
#     Population density (people per sq. km of land area)  \
# 12                                          14.058547
# 13                                          14.337645
# 14                                          14.631648
# 15                                          14.940699
# 16                                          15.265041
#
#     Solar Generation - TWh  Gas Consumption - TWh  Oil (TWh, direct energy)  \
# 12                     NaN                    NaN                       NaN
# 13                     NaN                    NaN                       NaN
# 14                     NaN                    NaN                       NaN
# 15                     NaN                    NaN                       NaN
# 16                     NaN                    NaN                       NaN
#
#     Annual CO2 emissions  prod of Electricity from wind (TWh) Entity_Category
# 12              490798.0                                  NaN         Country
# 13              688594.0                                  NaN         Country
# 14              706736.0                                  NaN         Country
# 15              838551.0                                  NaN         Country
# 16             1006917.0                                  NaN         Country

# %%
df_original.describe()
# Out:
#                Year  Fossil fuels (% equivalent primary energy)  \
# count  17013.000000                                 6068.000000
# mean    1992.379533                                   85.831892
# std       17.069374                                   14.603942
# min     1961.000000                                   12.804697
# 25%     1978.000000                                   80.509890
# 50%     1993.000000                                   90.139271
# 75%     2007.000000                                   96.528872
# max     2021.000000                                  100.000015
#
#        Fossil fuels (% growth)  Gas Production - TWh  Land area (sq. km)  \
# count              6034.000000           4053.000000        1.055900e+04
# mean                  3.317557           1775.709862        1.433329e+06
# std                  22.875763           4042.829666        9.901976e+06
# min                 -49.590828              0.000000        1.000000e+01
# 25%                  -0.531910             44.498001        2.318000e+04
# 50%                   2.589911            192.537277        1.118900e+05
# 75%                   5.987856            992.275024        4.994600e+05
# max                1553.104980          40368.828125        1.299870e+08
#
#        Unnamed: 0.1.1.1  Coal Consumption - TWh  \
# count      13164.000000             6134.000000
# mean        6581.873215             1625.004354
# std         3800.896830             4907.816698
# min            0.000000                0.000000
# 25%         3290.750000                4.537538
# 50%         6581.500000               46.895945
# 75%         9872.250000              442.860115
# max        13180.000000            45161.207031
#
#        Renewables per capita (kWh - equivalent)  Wind Generation - TWh  \
# count                               4862.000000            5939.000000
# mean                                   4.339072              13.805802
# std                                   12.693478              81.229086
# min                                    0.000000               0.000000
# 25%                                    0.208465               0.000000
# 50%                                    0.899160               0.000000
# 75%                                    3.228757               0.221320
# max                                  153.883406            1861.939819
#
#        prod of Other renewables including bioenergy (TWh)  \
# count                                        8899.000000
# mean                                           10.535739
# std                                            45.642700
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.020000
# 75%                                             1.333982
# max                                           762.782654
#
#        Fossil fuels per capita (kWh)  Fossil fuels (TWh)  \
# count                    4840.000000         6068.000000
# mean                    31653.758962         5136.950645
# std                     33092.712344        13737.030117
# min                       155.807388            0.097381
# 25%                     10325.921631          149.484257
# 50%                     25337.834961          418.682419
# 75%                     40323.159180         1808.173248
# max                    308704.218750       136131.468750
#
#        Oil Production - TWh  Coal Production - TWh  Hydro Generation - TWh  \
# count           4408.000000            2500.000000             6153.000000
# mean            3466.583599            3274.685893              136.736280
# std             6955.447481            6908.166717              374.128795
# min                0.000000               0.339596                0.000000
# 25%              100.963156              38.597149                1.389000
# 50%              467.141678             357.479385               10.712626
# 75%             3527.187439            2806.387512               59.555000
# max            52181.949219           46550.605469             4345.990234
#
#        Unnamed: 0.1.1  prod of Electricity from solar (TWh)  \
# count    13164.000000                           8939.000000
# mean      6581.873215                              4.423860
# std       3800.896830                             37.610140
# min          0.000000                              0.000000
# 25%       3290.750000                              0.000000
# 50%       6581.500000                              0.000000
# 75%       9872.250000                              0.010000
# max      13180.000000                           1032.501221
#
#        prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# count                           9170.000000  13164.000000
# mean                             105.856874   6581.873215
# std                              346.000705   3800.896830
# min                                0.000000      0.000000
# 25%                                0.100000   3290.750000
# 50%                                3.565500   6581.500000
# 75%                               28.667310   9872.250000
# max                             4345.990234  13180.000000
#
#        Gas (TWh, direct energy)  \
# count                 57.000000
# mean               21492.190695
# std                 9564.826179
# min                 6303.798828
# 25%                14118.032227
# 50%                20265.484375
# 75%                29315.390625
# max                40374.605469
#
#        Annual change in primary energy consumption (%)  \
# count                                     12261.000000
# mean                                          4.125264
# std                                          27.879834
# min                                         -95.005081
# 25%                                          -0.349981
# 50%                                           2.460420
# 75%                                           6.231642
# max                                        1553.104980
#
#        Geo Biomass Other - TWh  Coal (TWh, direct energy)  \
# count              5948.000000                  57.000000
# mean                 12.445990               28584.640556
# std                  45.803265               10007.255369
# min                   0.000000               16060.809570
# 25%                   0.000000               20363.539062
# 50%                   0.201000               25963.681641
# 75%                   3.617000               40175.359375
# max                 762.782654               45161.207031
#
#        Per capita electricity (kWh)  Oil Consumption - TWh  \
# count                   6220.000000            6160.000000
# mean                    3950.509462            2228.388291
# std                     5026.958829            5840.259523
# min                        0.000000               0.097381
# 25%                      596.250275              80.953899
# 50%                     2502.079101             208.418251
# 75%                     5627.821900             999.276443
# max                    56781.601560           53368.628906
#
#        Renewables (% electricity)  \
# count                 7008.000000
# mean                    30.488270
# std                     30.934145
# min                      0.000000
# 25%                      3.552361
# 50%                     18.145459
# 75%                     53.127329
# max                    100.000000
#
#        Population density (people per sq. km of land area)  \
# count                                        9717.000000
# mean                                          161.785499
# std                                           475.889730
# min                                             0.098625
# 25%                                            17.792095
# 50%                                            60.702633
# 75%                                           138.575929
# max                                          7965.878492
#
#        Solar Generation - TWh  Gas Consumption - TWh  \
# count             5924.000000            6094.000000
# mean                 5.047541            1228.198540
# std                 38.265463            3413.741868
# min                  0.000000               0.000000
# 25%                  0.000000              12.293094
# 50%                  0.000000              81.496605
# 75%                  0.016565             429.343689
# max               1032.501221           40374.605469
#
#        Oil (TWh, direct energy)  Annual CO2 emissions  \
# count                 57.000000          1.372300e+04
# mean               39160.740543          4.750953e+08
# std                 8988.199100          2.184178e+09
# min                17989.603516          3.664000e+03
# 25%                33680.054688          6.998240e+05
# 50%                38151.847656          7.081458e+06
# 75%                47172.609375          6.293776e+07
# max                53368.628906          3.670250e+10
#
#        prod of Electricity from wind (TWh)
# count                          8953.000000
# mean                             12.191714
# std                              81.726038
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.040000
# max                            1861.939819

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### World

# %%
category_filter = "World"

df = df_original.copy().loc[df_original['Entity_Category'] == category_filter]

# %%
df.head()
# Out:
#       Entity  Year Code Region Income group Lending category  \
# 27626  World  1961  WLD    NaN          NaN              NaN
# 27627  World  1962  WLD    NaN          NaN              NaN
# 27628  World  1963  WLD    NaN          NaN              NaN
# 27629  World  1964  WLD    NaN          NaN              NaN
# 27630  World  1965  WLD    NaN          NaN              NaN
#
#        Fossil fuels (% equivalent primary energy)  Fossil fuels (% growth)  \
# 27626                                         NaN                      NaN
# 27627                                         NaN                      NaN
# 27628                                         NaN                      NaN
# 27629                                         NaN                      NaN
# 27630                                    93.37812                      NaN
#
#        Gas Production - TWh  Land area (sq. km)  Unnamed: 0.1.1.1  \
# 27626                   NaN        1.296290e+08               NaN
# 27627                   NaN        1.296290e+08               NaN
# 27628                   NaN        1.296290e+08               NaN
# 27629                   NaN        1.296290e+08               NaN
# 27630                   NaN        1.296290e+08           12404.0
#
#        Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# 27626                     NaN                                       NaN
# 27627                     NaN                                       NaN
# 27628                     NaN                                       NaN
# 27629                     NaN                                       NaN
# 27630            16140.178711                                  0.836891
#
#        Wind Generation - TWh  \
# 27626                    NaN
# 27627                    NaN
# 27628                    NaN
# 27629                    NaN
# 27630                    0.0
#
#        prod of Other renewables including bioenergy (TWh)  \
# 27626                                                NaN
# 27627                                                NaN
# 27628                                                NaN
# 27629                                                NaN
# 27630                                          17.985231
#
#        Fossil fuels per capita (kWh)  Fossil fuels (TWh)  \
# 27626                            NaN                 NaN
# 27627                            NaN                 NaN
# 27628                            NaN                 NaN
# 27629                            NaN                 NaN
# 27630                   12107.379883        40433.578125
#
#        Oil Production - TWh  Coal Production - TWh  Hydro Generation - TWh  \
# 27626                   NaN                    NaN                     NaN
# 27627                   NaN                    NaN                     NaN
# 27628                   NaN                    NaN                     NaN
# 27629                   NaN                    NaN                     NaN
# 27630          18231.082031                    NaN              923.198059
#
#        Unnamed: 0.1.1  prod of Electricity from solar (TWh)  \
# 27626             NaN                                   NaN
# 27627             NaN                                   NaN
# 27628             NaN                                   NaN
# 27629             NaN                                   NaN
# 27630         12404.0                                   0.0
#
#        prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# 27626                                   NaN           NaN
# 27627                                   NaN           NaN
# 27628                                   NaN           NaN
# 27629                                   NaN           NaN
# 27630                            923.198059       12404.0
#
#        Gas (TWh, direct energy)  \
# 27626                       NaN
# 27627                       NaN
# 27628                       NaN
# 27629                       NaN
# 27630               6303.798828
#
#        Annual change in primary energy consumption (%)  \
# 27626                                              NaN
# 27627                                              NaN
# 27628                                              NaN
# 27629                                              NaN
# 27630                                              NaN
#
#        Geo Biomass Other - TWh  Coal (TWh, direct energy)  \
# 27626                      NaN                        NaN
# 27627                      NaN                        NaN
# 27628                      NaN                        NaN
# 27629                      NaN                        NaN
# 27630                17.985231               16140.178711
#
#        Per capita electricity (kWh)  Oil Consumption - TWh  \
# 27626                           NaN                    NaN
# 27627                           NaN                    NaN
# 27628                           NaN                    NaN
# 27629                           NaN                    NaN
# 27630                           NaN           17989.603516
#
#        Renewables (% electricity)  \
# 27626                         NaN
# 27627                         NaN
# 27628                         NaN
# 27629                         NaN
# 27630                         NaN
#
#        Population density (people per sq. km of land area)  \
# 27626                                          23.695278
# 27627                                          24.103871
# 27628                                          24.606030
# 27629                                          25.111241
# 27630                                          25.627340
#
#        Solar Generation - TWh  Gas Consumption - TWh  \
# 27626                     NaN                    NaN
# 27627                     NaN                    NaN
# 27628                     NaN                    NaN
# 27629                     NaN                    NaN
# 27630                     0.0            6303.798828
#
#        Oil (TWh, direct energy)  Annual CO2 emissions  \
# 27626                       NaN          9.417463e+09
# 27627                       NaN          9.750057e+09
# 27628                       NaN          1.027152e+10
# 27629                       NaN          1.082886e+10
# 27630              17989.603516          1.131723e+10
#
#        prod of Electricity from wind (TWh) Entity_Category
# 27626                                  NaN           World
# 27627                                  NaN           World
# 27628                                  NaN           World
# 27629                                  NaN           World
# 27630                                  0.0           World

# %%
df.describe()
# Out:
#               Year  Fossil fuels (% equivalent primary energy)  \
# count    61.000000                                   57.000000
# mean   1991.000000                                   87.906087
# std      17.752934                                    3.220952
# min    1961.000000                                   82.211304
# 25%    1976.000000                                   85.727249
# 50%    1991.000000                                   86.512390
# 75%    2006.000000                                   91.053261
# max    2021.000000                                   93.378120
#
#        Fossil fuels (% growth)  Gas Production - TWh  Land area (sq. km)  \
# count                56.000000             52.000000        6.000000e+01
# mean                  2.216326          22949.439247        1.297172e+08
# std                   2.336746           8939.489789        1.359545e+05
# min                  -5.385285           9760.991211        1.296056e+08
# 25%                   0.696263          14695.416992        1.296271e+08
# 50%                   2.006173          21383.237305        1.296290e+08
# 75%                   3.579623          29644.438965        1.298508e+08
# max                   6.728780          40368.828125        1.299870e+08
#
#        Unnamed: 0.1.1.1  Coal Consumption - TWh  \
# count         57.000000               57.000000
# mean        6117.754386            28584.640556
# std          847.656144            10007.255369
# min         5978.000000            16060.809570
# 25%         5992.000000            20363.539062
# 50%         6006.000000            25963.681641
# 75%         6020.000000            40175.359375
# max        12404.000000            45161.207031
#
#        Renewables per capita (kWh - equivalent)  Wind Generation - TWh  \
# count                                 57.000000              57.000000
# mean                                   1.454433             228.345476
# std                                    0.482532             449.014082
# min                                    0.836891               0.000000
# 25%                                    1.183239               0.006000
# 50%                                    1.331868               5.697569
# 75%                                    1.565588             171.506699
# max                                    2.827960            1861.939819
#
#        prod of Other renewables including bioenergy (TWh)  \
# count                                          57.000000
# mean                                          208.390151
# std                                           205.724881
# min                                            17.985231
# 25%                                            46.499256
# 50%                                           135.519318
# 75%                                           294.843079
# max                                           762.782654
#
#        Fossil fuels per capita (kWh)  Fossil fuels (TWh)  \
# count                      57.000000           57.000000
# mean                    15760.118198        89237.569422
# std                      1366.411639        28102.326104
# min                     12107.379883        40433.578125
# 25%                     15112.447266        69261.773438
# 50%                     15486.079102        83911.687500
# 75%                     16869.917969       115948.109375
# max                     17811.734375       136131.468750
#
#        Oil Production - TWh  Coal Production - TWh  Hydro Generation - TWh  \
# count             57.000000              41.000000               57.000000
# mean           38535.582511           32946.541587             2431.294728
# std             8416.048570            8964.818754              985.437508
# min            18231.082031           21445.263672              923.198059
# 25%            33519.679688           25627.955078             1695.186157
# 50%            37619.203125           27938.126953             2341.457520
# 75%            46038.386719           42621.265625             3072.892334
# max            52181.949219           46550.605469             4345.990234
#
#        Unnamed: 0.1.1  prod of Electricity from solar (TWh)  \
# count       57.000000                             57.000000
# mean      6117.754386                             84.041714
# std        847.656144                            217.619927
# min       5978.000000                              0.000000
# 25%       5992.000000                              0.000000
# 50%       6006.000000                              0.556698
# 75%       6020.000000                              7.817910
# max      12404.000000                           1032.501221
#
#        prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# count                             57.000000     57.000000
# mean                            2431.294728   6117.754386
# std                              985.437508    847.656144
# min                              923.198059   5978.000000
# 25%                             1695.186157   5992.000000
# 50%                             2341.457520   6006.000000
# 75%                             3072.892334   6020.000000
# max                             4345.990234  12404.000000
#
#        Gas (TWh, direct energy)  \
# count                 57.000000
# mean               21492.190695
# std                 9564.826179
# min                 6303.798828
# 25%                14118.032227
# 50%                20265.484375
# 75%                29315.390625
# max                40374.605469
#
#        Annual change in primary energy consumption (%)  \
# count                                        56.000000
# mean                                          2.443004
# std                                           2.130705
# min                                          -3.985941
# 25%                                           1.005194
# 50%                                           2.243525
# 75%                                           3.768480
# max                                           6.708479
#
#        Geo Biomass Other - TWh  Coal (TWh, direct energy)  \
# count                57.000000                  57.000000
# mean                208.390151               28584.640556
# std                 205.724881               10007.255369
# min                  17.985231               16060.809570
# 25%                  46.499256               20363.539062
# 50%                 135.519318               25963.681641
# 75%                 294.843079               40175.359375
# max                 762.782654               45161.207031
#
#        Per capita electricity (kWh)  Oil Consumption - TWh  \
# count                     37.000000              57.000000
# mean                    2741.295427           39160.740543
# std                      481.483171            8988.199100
# min                     2032.845825           17989.603516
# 25%                     2283.061035           33680.054688
# 50%                     2648.546631           38151.847656
# 75%                     3185.902832           47172.609375
# max                     3599.092773           53368.628906
#
#        Renewables (% electricity)  \
# count                   37.000000
# mean                    20.348038
# std                      2.784003
# min                     17.162390
# 25%                     18.754833
# 50%                     19.407053
# 75%                     20.832720
# max                     27.864630
#
#        Population density (people per sq. km of land area)  \
# count                                          60.000000
# mean                                           41.154059
# std                                            10.862296
# min                                            23.695278
# 25%                                            31.761750
# 50%                                            41.073288
# 75%                                            50.297190
# max                                            59.731828
#
#        Solar Generation - TWh  Gas Consumption - TWh  \
# count               57.000000              57.000000
# mean                84.041714           21492.190695
# std                217.619927            9564.826179
# min                  0.000000            6303.798828
# 25%                  0.000000           14118.032227
# 50%                  0.556698           20265.484375
# 75%                  7.817910           29315.390625
# max               1032.501221           40374.605469
#
#        Oil (TWh, direct energy)  Annual CO2 emissions  \
# count                 57.000000          6.000000e+01
# mean               39160.740543          2.316182e+10
# std                 8988.199100          7.980183e+09
# min                17989.603516          9.417463e+09
# 25%                33680.054688          1.775768e+10
# 50%                38151.847656          2.265960e+10
# 75%                47172.609375          2.984797e+10
# max                53368.628906          3.670250e+10
#
#        prod of Electricity from wind (TWh)
# count                            57.000000
# mean                            228.345476
# std                             449.014082
# min                               0.000000
# 25%                               0.006000
# 50%                               5.697569
# 75%                             171.506699
# max                            1861.939819

# %%
x = 'Year'
c = 'Entity'

y = 'Annual CO2 emissions'

# %% [markdown]
# #### Lineplots - Yearly

# %%
sns.lineplot(data=df, x=x, y=y, hue=c)

plt.title(f"{x} x {y} per {category_filter}")
# Out:
# Text(0.5, 1.0, 'Year x Annual CO2 emissions per World')

# %%
y1 = ['Annual CO2 emissions']
y2 = ['Annual change in primary energy consumption (%)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue='variable', palette="Set2", legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue='variable', palette="Set1", linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")
# Out:
# Text(0.5, 1.0, "Year x ['Annual CO2 emissions', 'Annual change in primary energy consumption (%)'] per World")

# %%
y1 = ['Fossil fuels per capita (kWh)',]
y2 = ['Renewables per capita (kWh - equivalent)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue='variable', palette="Set2", legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue='variable', palette="Set1", linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")
# Out:
# Text(0.5, 1.0, "Year x ['Fossil fuels per capita (kWh)', 'Renewables per capita (kWh - equivalent)'] per World")

# %%
y1 = ['Solar Generation - TWh', 'prod of Electricity from solar (TWh)']
y2 = ['Fossil fuels per capita (kWh)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue='variable', palette="Set2", legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue='variable', palette="Set1", linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")
# Out:
# Text(0.5, 1.0, "Year x ['Solar Generation - TWh', 'prod of Electricity from solar (TWh)', 'Fossil fuels per capita (kWh)'] per World")

# %% [markdown]
# #### Correlation Heatmap - For Entity Across Metrics

# %%
corr = df[corr_columns].corr()

# %%
masked_heatmap()
plt.title(f"Correlation of Key Metrics across Years in Entity [{category_filter}]")
# Out:
# Text(0.5, 1.0, 'Correlation of Key Metrics across Years in Entity [World]')

# %% [markdown]
# ### Income Level

# %%
df_original['Entity_Category'].value_counts()
# Out:
# Country             13243
# Bp?                  1549
# Eia?                 1040
# Exlusive Regions      361
# Continent             344
# Income Level          244
# Ember?                110
# World                  61
# Other                  61
# Name: Entity_Category, dtype: int64

# %%
category_filter = "Income Level"

df = df_original.copy().loc[df_original['Entity_Category'] == category_filter]

# %%
df.head()
# Out:
#                       Entity  Year Code Region Income group Lending category  \
# 10966  High-Income Countries  1961  NaN    NaN          NaN              NaN
# 10967  High-Income Countries  1962  NaN    NaN          NaN              NaN
# 10968  High-Income Countries  1963  NaN    NaN          NaN              NaN
# 10969  High-Income Countries  1964  NaN    NaN          NaN              NaN
# 10970  High-Income Countries  1965  NaN    NaN          NaN              NaN
#
#        Fossil fuels (% equivalent primary energy)  Fossil fuels (% growth)  \
# 10966                                         NaN                      NaN
# 10967                                         NaN                      NaN
# 10968                                         NaN                      NaN
# 10969                                         NaN                      NaN
# 10970                                   92.775543                      NaN
#
#        Gas Production - TWh  Land area (sq. km)  Unnamed: 0.1.1.1  \
# 10966                   NaN                 NaN               NaN
# 10967                   NaN                 NaN               NaN
# 10968                   NaN                 NaN               NaN
# 10969                   NaN                 NaN               NaN
# 10970                   NaN                 NaN           12326.0
#
#        Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# 10966                     NaN                                       NaN
# 10967                     NaN                                       NaN
# 10968                     NaN                                       NaN
# 10969                     NaN                                       NaN
# 10970            10125.585938                                  2.634769
#
#        Wind Generation - TWh  \
# 10966                    NaN
# 10967                    NaN
# 10968                    NaN
# 10969                    NaN
# 10970                    0.0
#
#        prod of Other renewables including bioenergy (TWh)  \
# 10966                                                NaN
# 10967                                                NaN
# 10968                                                NaN
# 10969                                                NaN
# 10970                                          17.885233
#
#        Fossil fuels per capita (kWh)  Fossil fuels (TWh)  \
# 10966                            NaN                 NaN
# 10967                            NaN                 NaN
# 10968                            NaN                 NaN
# 10969                            NaN                 NaN
# 10970                        34896.5        28374.730469
#
#        Oil Production - TWh  Coal Production - TWh  Hydro Generation - TWh  \
# 10966                   NaN                    NaN                     NaN
# 10967                   NaN                    NaN                     NaN
# 10968                   NaN                    NaN                     NaN
# 10969                   NaN                    NaN                     NaN
# 10970           8608.763672                    NaN              705.694092
#
#        Unnamed: 0.1.1  prod of Electricity from solar (TWh)  \
# 10966             NaN                                   NaN
# 10967             NaN                                   NaN
# 10968             NaN                                   NaN
# 10969             NaN                                   NaN
# 10970         12326.0                                   0.0
#
#        prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# 10966                                   NaN           NaN
# 10967                                   NaN           NaN
# 10968                                   NaN           NaN
# 10969                                   NaN           NaN
# 10970                            705.694092       12326.0
#
#        Gas (TWh, direct energy)  \
# 10966                       NaN
# 10967                       NaN
# 10968                       NaN
# 10969                       NaN
# 10970                       NaN
#
#        Annual change in primary energy consumption (%)  \
# 10966                                              NaN
# 10967                                              NaN
# 10968                                              NaN
# 10969                                              NaN
# 10970                                              NaN
#
#        Geo Biomass Other - TWh  Coal (TWh, direct energy)  \
# 10966                      NaN                        NaN
# 10967                      NaN                        NaN
# 10968                      NaN                        NaN
# 10969                      NaN                        NaN
# 10970                17.885233                        NaN
#
#        Per capita electricity (kWh)  Oil Consumption - TWh  \
# 10966                           NaN                    NaN
# 10967                           NaN                    NaN
# 10968                           NaN                    NaN
# 10969                           NaN                    NaN
# 10970                           NaN           13575.577148
#
#        Renewables (% electricity)  \
# 10966                         NaN
# 10967                         NaN
# 10968                         NaN
# 10969                         NaN
# 10970                         NaN
#
#        Population density (people per sq. km of land area)  \
# 10966                                                NaN
# 10967                                                NaN
# 10968                                                NaN
# 10969                                                NaN
# 10970                                                NaN
#
#        Solar Generation - TWh  Gas Consumption - TWh  \
# 10966                     NaN                    NaN
# 10967                     NaN                    NaN
# 10968                     NaN                    NaN
# 10969                     NaN                    NaN
# 10970                     0.0            4673.567383
#
#        Oil (TWh, direct energy)  Annual CO2 emissions  \
# 10966                       NaN          6.297137e+09
# 10967                       NaN          6.600679e+09
# 10968                       NaN          6.952760e+09
# 10969                       NaN          7.300569e+09
# 10970                       NaN          7.545914e+09
#
#        prod of Electricity from wind (TWh) Entity_Category
# 10966                                  NaN    Income Level
# 10967                                  NaN    Income Level
# 10968                                  NaN    Income Level
# 10969                                  NaN    Income Level
# 10970                                  0.0    Income Level

# %%
df.describe()
# Out:
#               Year  Fossil fuels (% equivalent primary energy)  \
# count   244.000000                                  171.000000
# mean   1991.000000                                   89.395315
# std      17.643008                                    3.961506
# min    1961.000000                                   79.292038
# 25%    1976.000000                                   86.153561
# 50%    1991.000000                                   90.571709
# 75%    2006.000000                                   92.263870
# max    2021.000000                                   95.671173
#
#        Fossil fuels (% growth)  Gas Production - TWh  Land area (sq. km)  \
# count               168.000000            203.000000                 0.0
# mean                  3.469417           5713.456888                 NaN
# std                   8.093721           4964.952596                 NaN
# min                 -12.149286              0.000000                 NaN
# 25%                   1.098689            264.276413                 NaN
# 50%                   2.939725           6118.325684                 NaN
# 75%                   4.996863           8537.432617                 NaN
# max                  98.222099          19068.613281                 NaN
#
#        Unnamed: 0.1.1.1  Coal Consumption - TWh  \
# count        225.000000              171.000000
# mean        5164.995556             9367.830076
# std         3368.613917             6683.579268
# min         1862.000000              449.159424
# 25%         2698.000000             4125.774536
# 50%         5718.000000             9759.784180
# 75%         9132.000000            12099.454102
# max        12539.000000            27708.554688
#
#        Renewables per capita (kWh - equivalent)  Wind Generation - TWh  \
# count                                171.000000             171.000000
# mean                                   1.867653              75.437945
# std                                    1.782040             184.244260
# min                                    0.081123               0.000000
# 25%                                    0.283997               0.000000
# 50%                                    1.061095               0.388838
# 75%                                    3.540976              30.843562
# max                                    6.883817             929.272583
#
#        prod of Other renewables including bioenergy (TWh)  \
# count                                         193.000000
# mean                                           59.645270
# std                                            91.627820
# min                                             0.000000
# 25%                                             2.112300
# 50%                                            19.684008
# 75%                                            74.533669
# max                                           385.799042
#
#        Fossil fuels per capita (kWh)  Fossil fuels (TWh)  \
# count                     171.000000          171.000000
# mean                    21412.252189        28710.551440
# std                     18808.978401        18981.398904
# min                       919.215820         1022.205017
# 25%                      4847.473877        11389.486816
# 50%                     12450.393555        24806.148438
# 75%                     44505.830078        46922.021484
# max                     52244.367188        58635.714844
#
#        Oil Production - TWh  Coal Production - TWh  Hydro Generation - TWh  \
# count            225.000000             123.000000              171.000000
# mean            9207.432737           10762.281830              735.307679
# std             6968.022350            6985.285411              561.301775
# min               12.194840             835.380554               30.508142
# 25%             2613.189209            6415.516846              196.864944
# 50%             7515.976562           10877.906250              705.694092
# 75%            14975.213867           11728.530762             1203.226562
# max            25383.656250           29293.859375             2230.803467
#
#        Unnamed: 0.1.1  prod of Electricity from solar (TWh)  \
# count      225.000000                            193.000000
# mean      5164.995556                             24.538201
# std       3368.613917                             79.564569
# min       1862.000000                              0.000000
# 25%       2698.000000                              0.000000
# 50%       5718.000000                              0.010603
# 75%       9132.000000                              0.837612
# max      12539.000000                            513.403381
#
#        prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# count                            193.000000    225.000000
# mean                             657.537580   5164.995556
# std                              571.177889   3368.613917
# min                                0.160000   1862.000000
# 25%                              149.345871   2698.000000
# 50%                              491.293976   5718.000000
# 75%                             1164.543945   9132.000000
# max                             2230.803467  12539.000000
#
#        Gas (TWh, direct energy)  \
# count                       0.0
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#        Annual change in primary energy consumption (%)  \
# count                                       207.000000
# mean                                          3.163113
# std                                           7.412832
# min                                         -11.670905
# 25%                                           0.720334
# 50%                                           2.898777
# 75%                                           4.931581
# max                                          95.384125
#
#        Geo Biomass Other - TWh  Coal (TWh, direct energy)  \
# count               171.000000                        0.0
# mean                 67.225539                        NaN
# std                  94.736834                        NaN
# min                   0.000000                        NaN
# 25%                   5.465880                        NaN
# 50%                  24.964964                        NaN
# 75%                  82.411488                        NaN
# max                 385.799042                        NaN
#
#        Per capita electricity (kWh)  Oil Consumption - TWh  \
# count                    133.000000             171.000000
# mean                    3378.353503           12395.928611
# std                     3652.276890            9520.041176
# min                        0.457940             531.817078
# 25%                      456.813019            4248.859619
# 50%                     1400.210938            8558.723633
# 75%                     7380.317871           22452.874023
# max                     9985.499023           29155.564453
#
#        Renewables (% electricity)  \
# count                  133.000000
# mean                    25.145435
# std                     14.179119
# min                     13.453400
# 25%                     15.812326
# 50%                     20.258909
# 75%                     25.670504
# max                     65.129036
#
#        Population density (people per sq. km of land area)  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        Solar Generation - TWh  Gas Consumption - TWh  \
# count              171.000000             171.000000
# mean                27.665864            6946.793735
# std                 84.044199            5120.665625
# min                  0.000000              38.420399
# 25%                  0.000000            2938.063599
# 50%                  0.010000            5789.330078
# 75%                  1.114080            9679.897949
# max                513.403381           19902.830078
#
#        Oil (TWh, direct energy)  Annual CO2 emissions  \
# count                       0.0          2.400000e+02
# mean                        NaN          5.590303e+09
# std                         NaN          5.180332e+09
# min                         NaN          4.232722e+07
# 25%                         NaN          5.321648e+08
# 50%                         NaN          3.980009e+09
# 75%                         NaN          1.069604e+10
# max                         NaN          1.605437e+10
#
#        prod of Electricity from wind (TWh)
# count                           193.000000
# mean                             66.863827
# std                             175.016311
# min                               0.000000
# 25%                               0.000000
# 50%                               0.213121
# 75%                              18.056793
# max                             929.272583

# %% [markdown]
# #### Lineplots - Yearly

# %%
x = 'Year'
c = 'Entity'

y = 'Annual CO2 emissions'

# %%
sns.lineplot(data=df, x=x, y=y, hue=c)

plt.title(f"{x} x {y} per {category_filter}")
# Out:
# Text(0.5, 1.0, 'Year x Annual CO2 emissions per Income Level')

# %%
y1 = ['Annual CO2 emissions']
y2 = ['Annual change in primary energy consumption (%)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, palette="Set2", legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, palette="Set1", linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")
# Out:
# Text(0.5, 1.0, "Year x ['Annual CO2 emissions', 'Annual change in primary energy consumption (%)'] per Income Level")

# %%
y1 = ['Fossil fuels per capita (kWh)',]
y2 = ['Renewables per capita (kWh - equivalent)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")
# Out:
# Text(0.5, 1.0, "Year x ['Fossil fuels per capita (kWh)', 'Renewables per capita (kWh - equivalent)'] per Income Level")

# %%
y1 = ['Fossil fuels per capita (kWh)']
y2 = ['Solar Generation - TWh', 'prod of Electricity from solar (TWh)']


df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")
# Out:
# Text(0.5, 1.0, "Year x ['Fossil fuels per capita (kWh)', 'Solar Generation - TWh', 'prod of Electricity from solar (TWh)'] per Income Level")

# %% [markdown]
# #### Correlation Heatmap - For Entity Across Metrics

# %%
#TODO Multiplot for each Income Level
# corr = df[key_columns].corr()

# sns.heatmap(data=corr)
# plt.title(f"Correlation of Key Metrics across Years in Category [{category_filter}]")

# %% [markdown]
# #### Correlation Heatmap - For Key Metrics Across Entities in 2020

# %%
corr = df.loc[df['Year'] == 2020][corr_columns].corr()

masked_heatmap()
plt.title(f"Correlation of Key Metrics across each Category [{category_filter}]")
# Out:
# Text(0.5, 1.0, 'Correlation of Key Metrics across each Category [Income Level]')

# %% [markdown]
# ### Continent

# %%
category_filter = "Continent"

df = df_original.copy().loc[df_original['Entity_Category'] == category_filter]

# %%
df.head()
# Out:
#      Entity  Year Code Region Income group Lending category  \
# 149  Africa  1961  NaN    NaN          NaN              NaN
# 150  Africa  1962  NaN    NaN          NaN              NaN
# 151  Africa  1963  NaN    NaN          NaN              NaN
# 152  Africa  1964  NaN    NaN          NaN              NaN
# 153  Africa  1965  NaN    NaN          NaN              NaN
#
#      Fossil fuels (% equivalent primary energy)  Fossil fuels (% growth)  \
# 149                                         NaN                      NaN
# 150                                         NaN                      NaN
# 151                                         NaN                      NaN
# 152                                         NaN                      NaN
# 153                                    94.25251                      NaN
#
#      Gas Production - TWh  Land area (sq. km)  Unnamed: 0.1.1.1  \
# 149                   NaN                 NaN               NaN
# 150                   NaN                 NaN               NaN
# 151                   NaN                 NaN               NaN
# 152                   NaN                 NaN               NaN
# 153                   NaN                 NaN           12291.0
#
#      Coal Consumption - TWh  Renewables per capita (kWh - equivalent)  \
# 149                     NaN                                       NaN
# 150                     NaN                                       NaN
# 151                     NaN                                       NaN
# 152                     NaN                                       NaN
# 153              323.496124                                  0.128437
#
#      Wind Generation - TWh  \
# 149                    NaN
# 150                    NaN
# 151                    NaN
# 152                    NaN
# 153                    0.0
#
#      prod of Other renewables including bioenergy (TWh)  \
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
#
#      Fossil fuels per capita (kWh)  Fossil fuels (TWh)  Oil Production - TWh  \
# 149                            NaN                 NaN                   NaN
# 150                            NaN                 NaN                   NaN
# 151                            NaN                 NaN                   NaN
# 152                            NaN                 NaN                   NaN
# 153                    2106.226318          674.302673           1235.100952
#
#      Coal Production - TWh  Hydro Generation - TWh  Unnamed: 0.1.1  \
# 149                    NaN                     NaN             NaN
# 150                    NaN                     NaN             NaN
# 151                    NaN                     NaN             NaN
# 152                    NaN                     NaN             NaN
# 153                    NaN               13.905636         12291.0
#
#      prod of Electricity from solar (TWh)  \
# 149                                   NaN
# 150                                   NaN
# 151                                   NaN
# 152                                   NaN
# 153                                   NaN
#
#      prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# 149                                   NaN           NaN
# 150                                   NaN           NaN
# 151                                   NaN           NaN
# 152                                   NaN           NaN
# 153                             13.905636       12291.0
#
#      Gas (TWh, direct energy)  \
# 149                       NaN
# 150                       NaN
# 151                       NaN
# 152                       NaN
# 153                       NaN
#
#      Annual change in primary energy consumption (%)  Geo Biomass Other - TWh  \
# 149                                              NaN                      NaN
# 150                                              NaN                      NaN
# 151                                              NaN                      NaN
# 152                                              NaN                      NaN
# 153                                              NaN                      NaN
#
#      Coal (TWh, direct energy)  Per capita electricity (kWh)  \
# 149                        NaN                           NaN
# 150                        NaN                           NaN
# 151                        NaN                           NaN
# 152                        NaN                           NaN
# 153                        NaN                           NaN
#
#      Oil Consumption - TWh  Renewables (% electricity)  \
# 149                    NaN                         NaN
# 150                    NaN                         NaN
# 151                    NaN                         NaN
# 152                    NaN                         NaN
# 153             341.262756                         NaN
#
#      Population density (people per sq. km of land area)  \
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
# 152                                                NaN
# 153                                                NaN
#
#      Solar Generation - TWh  Gas Consumption - TWh  Oil (TWh, direct energy)  \
# 149                     NaN                    NaN                       NaN
# 150                     NaN                    NaN                       NaN
# 151                     NaN                    NaN                       NaN
# 152                     NaN                    NaN                       NaN
# 153                     NaN               9.543755                       NaN
#
#      Annual CO2 emissions  prod of Electricity from wind (TWh) Entity_Category
# 149           162078599.0                                  NaN       Continent
# 150           166426479.0                                  NaN       Continent
# 151           176448437.0                                  NaN       Continent
# 152           193763891.0                                  NaN       Continent
# 153           213784592.0                                  0.0       Continent

# %%
df.describe()
# Out:
#               Year  Fossil fuels (% equivalent primary energy)  \
# count   344.000000                                  285.000000
# mean   1992.020349                                   85.437044
# std      17.269165                                    9.023672
# min    1961.000000                                   60.153706
# 25%    1978.000000                                   81.722176
# 50%    1992.500000                                   89.619415
# 75%    2007.000000                                   92.074448
# max    2021.000000                                   94.883224
#
#        Fossil fuels (% growth)  Gas Production - TWh  Land area (sq. km)  \
# count               280.000000            260.000000        6.000000e+01
# mean                  2.599684           4514.057994        1.812250e+07
# std                   3.749343           3792.127104        5.101169e+03
# min                 -10.257816             30.172163        1.811306e+07
# 25%                   0.518677            872.655258        1.812460e+07
# 50%                   2.526265           3746.651489        1.812460e+07
# 75%                   5.072358           7806.816772        1.812460e+07
# max                  16.714907          14309.506836        1.812756e+07
#
#        Unnamed: 0.1.1.1  Coal Consumption - TWh  \
# count        324.000000              285.000000
# mean        2647.956790             5625.187544
# std         2509.215237             7350.825759
# min            0.000000               66.624680
# 25%          248.750000              507.246979
# 50%         1519.500000             4050.202148
# 75%         4824.250000             6721.992188
# max        12382.000000            36037.972656
#
#        Renewables per capita (kWh - equivalent)  Wind Generation - TWh  \
# count                                285.000000             273.000000
# mean                                   2.453497              46.780487
# std                                    1.936062             115.947183
# min                                    0.128437               0.000000
# 25%                                    0.321926               0.000000
# 50%                                    2.427273               0.190800
# 75%                                    4.404799              14.223822
# max                                    6.185515             785.607178
#
#        prod of Other renewables including bioenergy (TWh)  \
# count                                         279.000000
# mean                                           40.899666
# std                                            56.691913
# min                                             0.000000
# 25%                                             3.204722
# 50%                                            16.227060
# 75%                                            64.038774
# max                                           336.357239
#
#        Fossil fuels per capita (kWh)  Fossil fuels (TWh)  \
# count                     285.000000          285.000000
# mean                    22282.951734        17589.543097
# std                     20069.423194        16266.258445
# min                      2106.051270          674.302673
# 25%                      5029.313477         3225.641113
# 50%                     10257.729492        19134.830078
# 75%                     41212.937500        26455.843750
# max                     63749.539062        76744.687500
#
#        Oil Production - TWh  Coal Production - TWh  Hydro Generation - TWh  \
# count            285.000000             205.000000              285.000000
# mean            7655.494867            6143.792222              476.824946
# std             5029.618254            7268.643233              358.387674
# min             1235.100952              78.990776               13.905636
# 25%             3880.907471            1264.931396              149.045563
# 50%             7299.555176            4498.670898              506.040619
# 75%             8700.134766            7067.227051              670.596619
# max            23247.154297           33334.093750             1980.761597
#
#        Unnamed: 0.1.1  prod of Electricity from solar (TWh)  \
# count      324.000000                            267.000000
# mean      2647.956790                             17.426988
# std       2509.215237                             63.247649
# min          0.000000                              0.000000
# 25%        248.750000                              0.000000
# 50%       1519.500000                              0.009186
# 75%       4824.250000                              0.927751
# max      12382.000000                            579.658935
#
#        prod of Electricity from hydro (TWh)  Unnamed: 0.1  \
# count                            285.000000    324.000000
# mean                             476.824946   2647.956790
# std                              358.387674   2509.215237
# min                               13.905636      0.000000
# 25%                              149.045563    248.750000
# 50%                              506.040619   1519.500000
# 75%                              670.596619   4824.250000
# max                             1980.761597  12382.000000
#
#        Gas (TWh, direct energy)  \
# count                       0.0
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#        Annual change in primary energy consumption (%)  \
# count                                       319.000000
# mean                                          2.458146
# std                                           6.977064
# min                                         -95.005081
# 25%                                           0.177598
# 50%                                           2.534151
# 75%                                           4.852182
# max                                          36.785065
#
#        Geo Biomass Other - TWh  Coal (TWh, direct energy)  \
# count               279.000000                        0.0
# mean                 40.899666                        NaN
# std                  56.691913                        NaN
# min                   0.000000                        NaN
# 25%                   3.204722                        NaN
# 50%                  16.227060                        NaN
# 75%                  64.038774                        NaN
# max                 336.357239                        NaN
#
#        Per capita electricity (kWh)  Oil Consumption - TWh  \
# count                    185.000000             285.000000
# mean                    4025.658106            7709.957319
# std                     3378.704635            6004.410714
# min                      466.092743             341.262756
# 25%                     1042.379517            1734.740723
# 50%                     2628.798828            8636.170898
# 75%                     6556.126465           12275.271484
# max                    10285.139650           24867.578125
#
#        Renewables (% electricity)  \
# count                  185.000000
# mean                    29.350527
# std                     22.870495
# min                     12.360984
# 25%                     16.439018
# 50%                     17.990870
# 75%                     25.492777
# max                     82.105980
#
#        Population density (people per sq. km of land area)  \
# count                                          60.000000
# mean                                           15.683462
# std                                             2.794608
# min                                            11.145485
# 25%                                            13.293853
# 50%                                            15.405879
# 75%                                            18.128320
# max                                            20.405282
#
#        Solar Generation - TWh  Gas Consumption - TWh  \
# count              267.000000             285.000000
# mean                17.426988            4254.398770
# std                 63.247649            4016.079317
# min                  0.000000               9.543755
# 25%                  0.000000             521.825256
# 50%                  0.009186            2777.180664
# 75%                  0.927751            7569.074219
# max                579.658936           16249.497070
#
#        Oil (TWh, direct energy)  Annual CO2 emissions  \
# count                       0.0          3.210000e+02
# mean                        NaN          4.144626e+09
# std                         NaN          4.241829e+09
# min                         NaN          3.664000e+03
# 25%                         NaN          6.676582e+08
# 50%                         NaN          3.771441e+09
# 75%                         NaN          6.421483e+09
# max                         NaN          2.060859e+10
#
#        prod of Electricity from wind (TWh)
# count                           273.000000
# mean                             46.780487
# std                             115.947183
# min                               0.000000
# 25%                               0.000000
# 50%                               0.190800
# 75%                              14.223822
# max                             785.607178

# %% [markdown]
# #### Lineplots - Yearly

# %%
x = 'Year'
c = 'Entity'

y = 'Annual CO2 emissions'

# %%
sns.lineplot(data=df, x=x, y=y, hue=c)

plt.title(f"{x} x {y} per {category_filter}")
# Out:
# Text(0.5, 1.0, 'Year x Annual CO2 emissions per Continent')

# %%
y1 = ['Annual CO2 emissions']
y2 = ['Annual change in primary energy consumption (%)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")
# Out:
# Text(0.5, 1.0, "Year x ['Annual CO2 emissions', 'Annual change in primary energy consumption (%)'] per Continent")

# %%
y1 = ['Fossil fuels per capita (kWh)',]
y2 = ['Renewables per capita (kWh - equivalent)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")
# Out:
# Text(0.5, 1.0, "Year x ['Fossil fuels per capita (kWh)', 'Renewables per capita (kWh - equivalent)'] per Continent")

# %%
y1 = ['Fossil fuels per capita (kWh)']
y2 = ['Solar Generation - TWh', 'prod of Electricity from solar (TWh)']


df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")

# %% [markdown]
# #### Correlation Heatmap - For Entity Across Metrics

# %%
#TODO Multiplot for each Income Level
# corr = df[key_columns].corr()

# sns.heatmap(data=corr)
# plt.title(f"Correlation of Key Metrics across Years in Category [{category_filter}]")

# %% [markdown]
# #### Correlation Heatmap - For Key Metrics Across Entities in 2020

# %%
corr = df.loc[df['Year'] == 2020][corr_columns].corr()

masked_heatmap()
plt.title(f"Correlation of Key Metrics across each Category [{category_filter}]")

# %% [markdown]
# ### Specific Countries

# %%
df_original['Entity'].unique()

# %%
category_filter = "Country"

df = df_original.copy().loc[
    (df_original['Entity_Category'] == category_filter)
    & (df_original['Entity'].isin(country_list))
]

# %%
df.head()

# %%
df.describe()

# %% [markdown]
# #### Lineplots - Yearly

# %%
x = 'Year'
c = 'Entity'

y = 'Annual CO2 emissions'

# %%
sns.lineplot(data=df, x=x, y=y, hue=c)

plt.title(f"{x} x {y} per {category_filter}")

# %%
y1 = ['Annual CO2 emissions']
y2 = ['Annual change in primary energy consumption (%)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")

# %%
y1 = ['Fossil fuels per capita (kWh)',]
y2 = ['Renewables per capita (kWh - equivalent)']

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")

# %%
y1 = ['Fossil fuels per capita (kWh)']
y2 = ['Solar Generation - TWh', 'prod of Electricity from solar (TWh)']


df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y1, value_name=str(y1))
ax = sns.lineplot(data=df_viz, x=x, y=str(y1), hue=c, legend='auto')

ax2 = ax.twinx()

df_viz = pd.melt(df, id_vars=['Entity_Category', 'Entity', 'Year'], value_vars=y2, value_name=str(y2))
sns.lineplot(data=df_viz, x=x, y=str(y2), ax=ax2, hue=c, linestyle=':')

ax.figure.legend()
plt.title(f"{x} x {y1 + y2} per {category_filter}")

# %% [markdown]
# #### Correlation Heatmap - For Entity Across Metrics

# %%
#TODO Multiplot for each Income Level
# corr = df[key_columns].corr()

# sns.heatmap(data=corr)
# plt.title(f"Correlation of Key Metrics across Years in Category [{category_filter}]")

# %% [markdown]
# #### Correlation Heatmap - For Key Metrics Across Entities in 2020

# %%
corr = df.loc[df['Year'] == 2020][corr_columns].corr()

masked_heatmap()
plt.title(f"Correlation of Key Metrics across each Category [{category_filter}]")
